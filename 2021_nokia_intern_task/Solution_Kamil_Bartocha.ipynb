# %% [markdown]
# ## Data description
# For each CA 2 csv files are created: x_train and y_train. x_train file has a vector of rational numbers per each row. These numbers depict assessment of an object via given assessment model. Values in single column (i.e. column 1) of one file (i.e. x_train_CA1) were produced with same model. Corresponding y_train has an expected binary label (with a noise) related to a row in x_train file. In that sense 𝑦=𝑓𝐶𝐴(𝑥).

# %% [markdown]
# ## Goal
#
# Using provided data and performing its analysis build prediction model that based on x vector will produce y value without knowing function 𝑓𝐶𝐴 (frankly, we do not know it either!).

# %% [markdown]
# ## Expected outcome
#
# A Jupyter (not to be mixed with Jupiter, we are not having any premises on that planet) notebook containing description of data, its analysis and information about reason and purpose of each step, its input, output and result. Notebook should produce a final model or models that based on x vector predicts y value for each CA with analysis of results.

# %% [markdown]
# ## Mudules import

# %%
import numpy as np
import pandas as pd
import os
import joblib
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score
from time import time

# %% [markdown]
# ## Data Load and describe

# %%
def describe_data(train_data, labels_data):
    print(train_data.describe())
    print(labels_data.describe())

def describe_shape(CA_number, train_data, labels_data):
    print(f"shape for train data in set number {CA_number}: ", train[CA_number].shape)
    print(f"shape for labels in set number  {CA_number}: ",   labels[CA_number].shape)
    print(80*"-")

# %%
train = []
labels = []

for CA_number in range(1,18):
    train_path = os.getcwd() + f'\\dataset\\x_train_CA{CA_number}.csv'
    labels_path = os.getcwd() + f'\\dataset\\y_train_CA{CA_number}.csv'
    
    train_data = pd.read_csv(train_path, header=None)
    labels_data = pd.read_csv(labels_path, header=None)
    
    describe_data(train_data, labels_data)
    train.append(np.array(train_data))
    labels.append(np.array(labels_data))
    describe_shape(CA_number-1, train_data, labels_data)
# Out:
#                 0            1            2            3            4   \
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000
# mean      0.406296     0.302534     0.389756     0.367475     0.406316
# std       0.389307     0.323628     0.390292     0.384839     0.389539
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.005148     0.000239     0.003323     0.000565     0.004901
# 50%       0.340362     0.312962     0.329896     0.322059     0.337146
# 75%       0.679549     0.658765     0.677412     0.672623     0.680219
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   ...  \
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000  ...
# mean      0.302119     0.390031     0.367795     0.099622     0.096031  ...
# std       0.323106     0.389898     0.384444     0.262318     0.256830  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.001013     0.006153     0.002287     0.000000     0.000000  ...
# 50%       0.310948     0.327624     0.322533     0.003816     0.002947  ...
# 75%       0.655968     0.676093     0.674163     0.018795     0.017718  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#                 86           87           88           89           90  \
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000
# mean      0.112631     0.109139     0.078453     0.075324     0.078828
# std       0.215503     0.207789     0.185831     0.178440     0.182490
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000641     0.000000     0.000000     0.000000
# 50%       0.019082     0.022194     0.015427     0.016602     0.016054
# 75%       0.103529     0.091997     0.056775     0.056681     0.065065
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 91           92           93           94           95
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000
# mean      0.078777     0.080190     0.078643     0.078273     0.078304
# std       0.184609     0.182633     0.180890     0.185323     0.183647
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.014165     0.015333     0.015420     0.015567     0.014737
# 75%       0.057171     0.059602     0.065865     0.053930     0.053956
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 96 columns]
#                  0
# count  1060.000000
# mean      0.053012
# std       0.209649
# min       0.000000
# 25%       0.000000
# 50%       0.002117
# 75%       0.014140
# max       1.000000
# shape for train data in set number 0:  (1060, 96)
# shape for labels in set number  0:  (1060, 1)
# --------------------------------------------------------------------------------
#                 0            1            2            3            4   \
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000
# mean      0.510109     0.522147     0.498908     0.483002     0.509980
# std       0.395742     0.390093     0.399011     0.399003     0.396341
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.016468     0.019688     0.014971     0.013772     0.014838
# 50%       0.649527     0.651865     0.646894     0.643445     0.649802
# 75%       0.982286     0.981320     0.981937     0.979775     0.981832
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   ...  \
# count  1060.000000  1060.000000  1060.000000  1060.000000  1060.000000  ...
# mean      0
\
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean      0.255377     0.252367     0.223157     0.218722     0.216300
# std       0.283260     0.281162     0.286217     0.281647     0.285372
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.048495     0.042179     0.021557     0.024465     0.020121
# 50%       0.139782     0.149063     0.109345     0.096680     0.095223
# 75%       0.350978     0.375077     0.287816     0.291527     0.275997
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 91           92           93           94           95
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean      0.212738     0.213406     0.217351     0.217808     0.215007
# std       0.279381     0.281821     0.282284     0.287013     0.281566
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.021433     0.021310     0.021486     0.020781     0.024068
# 50%       0.104954     0.098603     0.104884     0.092070     0.092568
# 75%       0.273637     0.256382     0.280467     0.286430     0.284659
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 96 columns]
#                  0
# count  1059.000000
# mean      0.127586
# std       0.324236
# min       0.000000
# 25%       0.000000
# 50%       0.003185
# 75%       0.018082
# max       1.000000
# shape for train data in set number 15:  (1059, 96)
# shape for labels in set number  15:  (1059, 1)
# --------------------------------------------------------------------------------
#                0           1           2           3           4           5   \
# count  923.000000  923.000000  923.000000  923.000000  923.000000  923.000000
# mean     0.369569    0.267458    0.351858    0.326766    0.369520    0.266606
# std      0.372365    0.300139    0.371485    0.361389    0.371856    0.300057
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.002866    0.000000    0.000000    0.000000    0.002388    0.000000
# 50%      0.322209    0.022450    0.319321    0.312011    0.326814    0.022057
# 75%      0.672899    0.650008    0.666249    0.660558    0.668269    0.648695
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9   ...          86  \
# count  923.000000  923.000000  923.000000  923.000000  ...  923.000000
# mean     0.351699    0.326873    0.046487    0.052134  ...    0.047660
# std      0.371370    0.361479    0.173500    0.184139  ...    0.123064
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000980    0.000397    0.000000    0.000000  ...    0.000000
# 50%      0.319432    0.313098    0.000304    0.002184  ...    0.011895
# 75%      0.666275    0.664904    0.014261    0.014258  ...    0.039563
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#                87          88          89          90          91          92  \
# count  923.000000  923.000000  923.000000  923.000000  923.000000  923.000000
# mean     0.045947    0.030109    0.037342    0.036687    0.034516    0.032988
# std      0.113204    0.109354    0.108950    0.113660    0.117039    0.112205
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.012948    0.005674    0.009644    0.007693    0.006723    0.008059
# 75%      0.044453    0.019130    0.024518    0.022337    0.021010    0.021770
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                93          94          95
# count  923.000000  923.000000  923.000000
# mean     0.035380    0.032483    0.029761
# std      0.108956    0.113599    0.109116
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.008795    0.007738    0.005394
# 75%      0.023143    0.021108    0.019677
# max      1.000000    1.000000    1.000000
#
# [8 rows x 96 columns]
#                 0
# count  923.000000
# mean     0.022586
# std      0.125562
# min      0.000000
# 25%      0.000000
# 50%      0.001185
# 75%      0.013369
# max      1.000000
# shape for train data in set number 16:  (923, 96)
# shape for labels in set number  16:  (923, 1)
# --------------------------------------------------------------------------------

# %% [markdown]
# ##### Purpose
#  Load data into numpy array, first glance at data structure by pandas.decsribe. First conclusions:
#  * values between 0 and 1 (continous), noise need to be reduced
#  * sets: 6, 13, 16, 17 have diferent shapes, others 1060 x 96

# %% [markdown]
# ## Labels convert

# %%
def convert_to_binary(CA_number):
    for i in range (0, len(labels[CA_number])):
        if labels[CA_number][i] >= 0.5:
            labels[CA_number][i] = 1
        else:
            labels[CA_number][i] = 0

for CA_number in range(1, 18):
    convert_to_binary(CA_number - 1)

# %% [markdown]
# ##### Purpose
# As we can find in description "y_train has an expected binary label (with a noise)" labels are converted to binary

# %% [markdown]
# ## Split into train, validation, and test set

# %%
X_train = []
X_test  = []
X_val   = []
y_train = []
y_test  = []
y_val   = []

def split_train_val_test(CA_number):
    # train set 60%, rest 40%, _t-temporary variable
    X_train_t, X_test_t, y_train_t, y_test_t = train_test_split(train[CA_number],
                                                                labels[CA_number],
                                                                test_size=0.4,
                                                                random_state=42
                                                               )
    # validation 20%, test set 40%
    X_val_t, X_test_t, y_val_t, y_test_t = train_test_split(X_test_t,
                                                            y_test_t,
                                                            test_size=0.5,
                                                            random_state=42
                                                           )
    X_train.append(np.array(X_train_t))
    X_val.append(np.array(X_val_t))
    X_test.append(np.array(X_test_t))
    y_train.append(np.array(y_train_t))
    y_val.append(np.array(y_val_t))
    y_test.append(np.array(y_test_t))

# %%
# split for all CA 
for CA_number in range(0, 17):
    split_train_val_test(CA_number)

# %% [markdown]
# ##### Purpose
# For each CA data are splited in ratio: 60% train set, 20% validation set, 20% test set. Validation set for hyperparemeters tuning, and test set for final result verification

# %% [markdown]
# ### Train models
#
# After quick tests using basics ML algorithms i have discoverd that all of them perform really good. I Asume (and hope) that chosing one with best performence isn't important it this task, so i choosee support vector machines becouse i like it. Then i have trainted models with GridSearch for fast parameters selection

# %%
def print_results(results):
    '''Prints best parameters and results of training 
    for each parameter in GridSearch. 
    '''
    
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean, 3)} (+/-{round(std * 2, 3)}) for {params}')

# %%
def train_and_save_model(CA_number):
    '''Trains model(SVM) using GridSearch (five cross validation sets)
    with parameters stored in dict and save best model in pickle
    '''
   
    model_path = os.getcwd() + f'\\models\\SVM_model_CA_{CA_number + 1}.pkl'
    svc = SVC()
    parameters = {
        'kernel': ['linear', 'rbf'],
        'C': [0.001, 0.1, 1, 10]
    }

    cv = GridSearchCV(svc, parameters, cv=5)
    cv.fit(X_train[CA_number], y_train[CA_number].ravel())
    
    print_results(cv)
    joblib.dump(cv.best_estimator_, model_path)

# %%
for CA_number in range(0, 17):
    train_and_save_model(CA_number)
# Out:
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.954 (+/-0.006) for {'C': 0.001, 'kernel': 'linear'}
# 0.954 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 0.98 (+/-0.008) for {'C': 0.1, 'kernel': 'linear'}
# 0.97 (+/-0.006) for {'C': 0.1, 'kernel': 'rbf'}
# 0.997 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.012) for {'C': 1, 'kernel': 'rbf'}
# 0.997 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.987 (+/-0.008) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.1, 'kernel': 'rbf'}
#
# 0.877 (+/-0.007) for {'C': 0.001, 'kernel': 'linear'}
# 0.877 (+/-0.007) for {'C': 0.001, 'kernel': 'rbf'}
# 0.937 (+/-0.022) for {'C': 0.1, 'kernel': 'linear'}
# 0.937 (+/-0.017) for {'C': 0.1, 'kernel': 'rbf'}
# 0.932 (+/-0.029) for {'C': 1, 'kernel': 'linear'}
# 0.936 (+/-0.023) for {'C': 1, 'kernel': 'rbf'}
# 0.917 (+/-0.044) for {'C': 10, 'kernel': 'linear'}
# 0.931 (+/-0.038) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.934 (+/-0.026) for {'C': 0.001, 'kernel': 'linear'}
# 0.753 (+/-0.007) for {'C': 0.001, 'kernel': 'rbf'}
# 0.981 (+/-0.013) for {'C': 0.1, 'kernel': 'linear'}
# 0.936 (+/-0.025) for {'C': 0.1, 'kernel': 'rbf'}
# 0.995 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.961 (+/-0.028) for {'C': 1, 'kernel': 'rbf'}
# 0.987 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.986 (+/-0.012) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.959 (+/-0.006) for {'C': 0.001, 'kernel': 'linear'}
# 0.959 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 0.98 (+/-0.016) for {'C': 0.1, 'kernel': 'linear'}
# 0.965 (+/-0.008) for {'C': 0.1, 'kernel': 'rbf'}
# 0.98 (+/-0.023) for {'C': 1, 'kernel': 'linear'}
# 0.98 (+/-0.016) for {'C': 1, 'kernel': 'rbf'}
# 0.965 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.021) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.1, 'kernel': 'linear'}
#
# 0.97 (+/-0.006) for {'C': 0.001, 'kernel': 'linear'}
# 0.97 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 1.0 (+/-0.0) for {'C': 0.1, 'kernel': 'linear'}
# 0.97 (+/-0.006) for {'C': 0.1, 'kernel': 'rbf'}
# 1.0 (+/-0.0) for {'C': 1, 'kernel': 'linear'}
# 0.997 (+/-0.008) for {'C': 1, 'kernel': 'rbf'}
# 1.0 (+/-0.0) for {'C': 10, 'kernel': 'linear'}
# 0.998 (+/-0.006) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.922 (+/-0.001) for {'C': 0.001, 'kernel': 'linear'}
# 0.922 (+/-0.001) for {'C': 0.001, 'kernel': 'rbf'}
# 0.991 (+/-0.027) for {'C': 0.1, 'kernel': 'linear'}
# 0.97 (+/-0.034) for {'C': 0.1, 'kernel': 'rbf'}
# 0.998 (+/-0.007) for {'C': 1, 'kernel': 'linear'}
# 0.969 (+/-0.036) for {'C': 1, 'kernel': 'rbf'}
# 0.995 (+/-0.014) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.016) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 10, 'kernel': 'rbf'}
#
# 0.967 (+/-0.006) for {'C': 0.001, 'kernel': 'linear'}
# 0.967 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 0.992 (+/-0.014) for {'C': 0.1, 'kernel': 'linear'}
# 0.984 (+/-0.01) for {'C': 0.1, 'kernel': 'rbf'}
# 0.992 (+/-0.01) for {'C': 1, 'kernel': 'linear'}
# 0.992 (+/-0.01) for {'C': 1, 'kernel': 'rbf'}
# 0.986 (+/-0.018) for {'C': 10, 'kernel': 'linear'}
# 0.994 (+/-0.012) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.939 (+/-0.035) for {'C': 0.001, 'kernel': 'linear'}
# 0.695 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 0.973 (+/-0.016) for {'C': 0.1, 'kernel': 'linear'}
# 0.939 (+/-0.046) for {'C': 0.1, 'kernel': 'rbf'}
# 0.975 (+/-0.015) for {'C': 1, 'kernel': 'linear'}
# 0.962 (+/-0.035) for {'C': 1, 'kernel': 'rbf'}
# 0.959 (+/-0.018) for {'C': 10, 'kernel': 'linear'}
# 0.965 (+/-0.029) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.1, 'kernel': 'linear'}
#
# 0.992 (+/-0.0) for {'C': 0.001, 'kernel': 'linear'}
# 0.992 (+/-0.0) for {'C': 0.001, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 0.1, 'kernel': 'linear'}
# 0.992 (+/-0.0) for {'C': 0.1, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 1, 'kernel': 'linear'}
# 0.995 (+/-0.008) for {'C': 1, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 10, 'kernel': 'linear'}
# 0.995 (+/-0.008) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.943 (+/-0.018) for {'C': 0.001, 'kernel': 'linear'}
# 0.873 (+/-0.005) for {'C': 0.001, 'kernel': 'rbf'}
# 0.943 (+/-0.015) for {'C': 0.1, 'kernel': 'linear'}
# 0.942 (+/-0.007) for {'C': 0.1, 'kernel': 'rbf'}
# 0.997 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.945 (+/-0.01) for {'C': 1, 'kernel': 'rbf'}
# 0.987 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.032) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.918 (+/-0.038) for {'C': 0.001, 'kernel': 'linear'}
# 0.819 (+/-0.001) for {'C': 0.001, 'kernel': 'rbf'}
# 0.937 (+/-0.041) for {'C': 0.1, 'kernel': 'linear'}
# 0.918 (+/-0.035) for {'C': 0.1, 'kernel': 'rbf'}
# 0.964 (+/-0.021) for {'C': 1, 'kernel': 'linear'}
# 0.931 (+/-0.035) for {'C': 1, 'kernel': 'rbf'}
# 0.953 (+/-0.033) for {'C': 10, 'kernel': 'linear'}
# 0.948 (+/-0.016) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.1, 'kernel': 'linear'}
#
# 0.948 (+/-0.012) for {'C': 0.001, 'kernel': 'linear'}
# 0.887 (+/-0.007) for {'C': 0.001, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 0.1, 'kernel': 'linear'}
# 0.951 (+/-0.012) for {'C': 0.1, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 1, 'kernel': 'linear'}
# 0.961 (+/-0.017) for {'C': 1, 'kernel': 'rbf'}
# 0.992 (+/-0.017) for {'C': 10, 'kernel': 'linear'}
# 0.994 (+/-0.018) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'rbf'}
#
# 0.959 (+/-0.036) for {'C': 0.001, 'kernel': 'linear'}
# 0.877 (+/-0.008) for {'C': 0.001, 'kernel': 'rbf'}
# 0.956 (+/-0.035) for {'C': 0.1, 'kernel': 'linear'}
# 0.957 (+/-0.037) for {'C': 0.1, 'kernel': 'rbf'}
# 0.948 (+/-0.041) for {'C': 1, 'kernel': 'linear'}
# 0.961 (+/-0.037) for {'C': 1, 'kernel': 'rbf'}
# 0.924 (+/-0.044) for {'C': 10, 'kernel': 'linear'}
# 0.959 (+/-0.038) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.972 (+/-0.008) for {'C': 0.001, 'kernel': 'linear'}
# 0.972 (+/-0.008) for {'C': 0.001, 'kernel': 'rbf'}
# 0.987 (+/-0.016) for {'C': 0.1, 'kernel': 'linear'}
# 0.972 (+/-0.008) for {'C': 0.1, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 1, 'kernel': 'linear'}
# 0.987 (+/-0.016) for {'C': 1, 'kernel': 'rbf'}
# 0.998 (+/-0.006) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.018) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.1, 'kernel': 'linear'}
#
# 0.954 (+/-0.006) for {'C': 0.001, 'kernel': 'linear'}
# 0.954 (+/-0.006) for {'C': 0.001, 'kernel': 'rbf'}
# 0.973 (+/-0.021) for {'C': 0.1, 'kernel': 'linear'}
# 0.954 (+/-0.006) for {'C': 0.1, 'kernel': 'rbf'}
# 0.964 (+/-0.026) for {'C': 1, 'kernel': 'linear'}
# 0.973 (+/-0.021) for {'C': 1, 'kernel': 'rbf'}
# 0.959 (+/-0.027) for {'C': 10, 'kernel': 'linear'}
# 0.965 (+/-0.024) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 1, 'kernel': 'rbf'}
#
# 0.877 (+/-0.008) for {'C': 0.001, 'kernel': 'linear'}
# 0.877 (+/-0.008) for {'C': 0.001, 'kernel': 'rbf'}
# 0.935 (+/-0.025) for {'C': 0.1, 'kernel': 'linear'}
# 0.935 (+/-0.027) for {'C': 0.1, 'kernel': 'rbf'}
# 0.937 (+/-0.036) for {'C': 1, 'kernel': 'linear'}
# 0.94 (+/-0.031) for {'C': 1, 'kernel': 'rbf'}
# 0.915 (+/-0.05) for {'C': 10, 'kernel': 'linear'}
# 0.934 (+/-0.044) for {'C': 10, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 10, 'kernel': 'linear'}
#
# 0.984 (+/-0.007) for {'C': 0.001, 'kernel': 'linear'}
# 0.984 (+/-0.007) for {'C': 0.001, 'kernel': 'rbf'}
# 0.987 (+/-0.014) for {'C': 0.1, 'kernel': 'linear'}
# 0.984 (+/-0.007) for {'C': 0.1, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 1, 'kernel': 'linear'}
# 0.984 (+/-0.007) for {'C': 1, 'kernel': 'rbf'}
# 1.0 (+/-0.0) for {'C': 10, 'kernel': 'linear'}
# 0.986 (+/-0.009) for {'C': 10, 'kernel': 'rbf'}

# %% [markdown]
# ##### Purpose
# Having all trained models in pickle files for quick and easy access later

# %% [markdown]
# ## Load models and evaluate

# %%
models = {}

for m_number in range(1, 18):
    models[m_number] = joblib.load(f'models/SVM_model_CA_{m_number}.pkl')

models
# Out:
# {1: SVC(C=1, kernel='linear'),
#  2: SVC(C=0.1),
#  3: SVC(C=1, kernel='linear'),
#  4: SVC(C=1, kernel='linear'),
#  5: SVC(C=0.1, kernel='linear'),
#  6: SVC(C=1, kernel='linear'),
#  7: SVC(C=10),
#  8: SVC(C=1, kernel='linear'),
#  9: SVC(C=0.1, kernel='linear'),
#  10: SVC(C=1, kernel='linear'),
#  11: SVC(C=1, kernel='linear'),
#  12: SVC(C=0.1, kernel='linear'),
#  13: SVC(C=1),
#  14: SVC(C=1, kernel='linear'),
#  15: SVC(C=0.1, kernel='linear'),
#  16: SVC(C=1),
#  17: SVC(C=10, kernel='linear')}

# %%
def evaluate_model(models, features, labels):
    ''' Loads model, predict decision for given X - features and y - labels
    calculate and print accuracy, precision, recall and time of execution
    '''
    start = time()
    pred  = models.predict(features)
    end   = time()
    
    accuracy  = round(accuracy_score(labels, pred), 3)
    precision = round(precision_score(labels, pred), 3)
    recall    = round(recall_score(labels, pred), 3)
    
    print(f'Accuracy: {accuracy} | Precision: {precision} |'
          f'Recall: {recall} | Latency: {round((end - start)*1000, 1)}ms')

# %% [markdown]
# ## Evaluate on validation sets
# Evaluate each model for every CA on validation set

# %%
for CA_number in range (1, 18):
    print(f'CA number: {CA_number}')      # CA_number - 1: array indexes starts with 0, models with 1
    evaluate_model(models[CA_number], X_val[CA_number - 1], y_val[CA_number - 1])
    print(80*'-')
# Out:
# CA number: 1
# Accuracy: 0.995 | Precision: 0.923 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 2
# Accuracy: 0.953 | Precision: 0.792 |Recall: 0.792 | Latency: 3.9ms
# --------------------------------------------------------------------------------
# CA number: 3
# Accuracy: 0.986 | Precision: 1.0 |Recall: 0.941 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 4
# Accuracy: 0.972 | Precision: 1.0 |Recall: 0.5 | Latency: 2.0ms
# --------------------------------------------------------------------------------
# CA number: 5
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 0.0ms
# --------------------------------------------------------------------------------
# CA number: 6
# Accuracy: 0.995 | Precision: 1.0 |Recall: 0.944 | Latency: 0.0ms
# --------------------------------------------------------------------------------
# CA number: 7
# Accuracy: 0.972 | Precision: 1.0 |Recall: 0.455 | Latency: 2.5ms
# --------------------------------------------------------------------------------
# CA number: 8
# Accuracy: 0.986 | Precision: 0.969 |Recall: 0.984 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 9
# Accuracy: 0.995 | Precision: 1.0 |Recall: 0.833 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 10
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 2.0ms
# --------------------------------------------------------------------------------
# CA number: 11
# Accuracy: 0.962 | Precision: 0.944 |Recall: 0.85 | Latency: 2.0ms
# --------------------------------------------------------------------------------
# CA number: 12
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.9ms
# --------------------------------------------------------------------------------
# CA number: 13
# Accuracy: 0.958 | Precision: 0.941 |Recall: 0.667 | Latency: 3.0ms
# --------------------------------------------------------------------------------
# CA number: 14
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 15
# Accuracy: 0.958 | Precision: 0.714 |Recall: 0.417 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 16
# Accuracy: 0.953 | Precision: 1.0 |Recall: 0.583 | Latency: 5.0ms
# --------------------------------------------------------------------------------
# CA number: 17
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Evaluate on test sets
#
# Evaluate each model for every CA on test set

# %%
for CA_number in range (1, 18):
    print(f'CA number: {CA_number}')      # CA_number - 1: array indexes starts with 0, models with 1
    evaluate_model(models[CA_number], X_test[CA_number - 1], y_test[CA_number - 1])
    print(80*'-')
# Out:
# CA number: 1
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 0.0ms
# --------------------------------------------------------------------------------
# CA number: 2
# Accuracy: 0.925 | Precision: 0.812 |Recall: 0.5 | Latency: 4.2ms
# --------------------------------------------------------------------------------
# CA number: 3
# Accuracy: 0.986 | Precision: 0.961 |Recall: 0.98 | Latency: 1.8ms
# --------------------------------------------------------------------------------
# CA number: 4
# Accuracy: 0.986 | Precision: 1.0 |Recall: 0.667 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 5
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 6
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 7
# Accuracy: 0.976 | Precision: 0.625 |Recall: 0.714 | Latency: 2.0ms
# --------------------------------------------------------------------------------
# CA number: 8
# Accuracy: 0.948 | Precision: 0.924 |Recall: 0.91 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 9
# Accuracy: 0.995 | Precision: 1.0 |Recall: 0.667 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 10
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 11
# Accuracy: 0.967 | Precision: 0.932 |Recall: 0.911 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 12
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 2.0ms
# --------------------------------------------------------------------------------
# CA number: 13
# Accuracy: 0.939 | Precision: 0.941 |Recall: 0.571 | Latency: 3.0ms
# --------------------------------------------------------------------------------
# CA number: 14
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 0.0ms
# --------------------------------------------------------------------------------
# CA number: 15
# Accuracy: 0.967 | Precision: 0.625 |Recall: 0.556 | Latency: 1.0ms
# --------------------------------------------------------------------------------
# CA number: 16
# Accuracy: 0.925 | Precision: 0.8 |Recall: 0.571 | Latency: 4.0ms
# --------------------------------------------------------------------------------
# CA number: 17
# Accuracy: 1.0 | Precision: 1.0 |Recall: 1.0 | Latency: 1.0ms
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Single predict
# Based on X vector predicts y value for each CA.

# %%
def predict(X, y, CA_number):
    ''' Predicts label(y) for given vector(X)'''
    X = X.reshape(1, -1) # for fit into predict method
    pred = models[CA_number].predict(X)
    
    if pred == y:
        state = ' CORRECT'
    else:
        state = 'WRONG'
    
    print(f' CA: {CA_number} y = {y}, prediction: {pred} {state}')
    
def predict_all(X, y):
    '''Predicts label(y) for all CA for given X - vector '''
    predicts = []
    for CA_number in range(1,18):
        pred = predict(X, y, CA_number)
        predicts.append(pred)

# %%
X = X_test[15][3] # radom vector from test set and its label
y = y_test[15][3]

predict_all(X, y)
# Out:
#  CA: 1 y = [1.], prediction: [0.] WRONG
#  CA: 2 y = [1.], prediction: [0.] WRONG
#  CA: 3 y = [1.], prediction: [1.]  CORRECT
#  CA: 4 y = [1.], prediction: [0.] WRONG
#  CA: 5 y = [1.], prediction: [1.]  CORRECT
#  CA: 6 y = [1.], prediction: [1.]  CORRECT
#  CA: 7 y = [1.], prediction: [1.]  CORRECT
#  CA: 8 y = [1.], prediction: [1.]  CORRECT
#  CA: 9 y = [1.], prediction: [1.]  CORRECT
#  CA: 10 y = [1.], prediction: [1.]  CORRECT
#  CA: 11 y = [1.], prediction: [0.] WRONG
#  CA: 12 y = [1.], prediction: [1.]  CORRECT
#  CA: 13 y = [1.], prediction: [0.] WRONG
#  CA: 14 y = [1.], prediction: [1.]  CORRECT
#  CA: 15 y = [1.], prediction: [0.] WRONG
#  CA: 16 y = [1.], prediction: [0.] WRONG
#  CA: 17 y = [1.], prediction: [1.]  CORRECT

# %% [markdown]
# ## Conclusions and additional informations

# %% [markdown]
# * All models performs well, Accuracy > 0.925
# * Its hard to eliminate or choosee CA number based on model prediciton - data is similar for all CA, but was it a goal for this task?
# * Data analysis could be performed better, maybe knowledge about data source and models destinity would make work with synthetic data easier.
# * As i have used one model, validation set was useless - in normal case i would choosee between best model at this stage and check performence on test set. But i leave it as it is.
# * Some parts arent explained, I believe that those lines of code speak for themselfs.
